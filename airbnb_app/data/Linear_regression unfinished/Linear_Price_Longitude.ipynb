# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Read the csv file into a pandas DataFrame
abnb_90 = pd.read_csv('../abnb_df_90.csv')

# %%
abnb_nrows = len(abnb_90.index)
abnb_nrows
# Out:
# 28127

# %%
# Assign the data to X and y
# Note: Sklearn requires a two-dimensional array of values
# so we use reshape to create this

X = abnb_90.longitude.values.reshape(-1, 1)
y = abnb_90.price.values.reshape(-1, 1)

print("Shape: ", X.shape, y.shape)
X
# Out:
# Shape:  (28127, 1) (28127, 1)
# array([[-118.2764233],
#        [-118.3748494],
#        [-118.268139 ],
#        ...,
#        [-118.3578362],
#        [-118.7701218],
#        [-118.4761935]])

# %%
# Plot the data

plt.scatter(X, y)

# %%
# Create the model and fit the model to the data

from sklearn.linear_model import LinearRegression

model = LinearRegression()

# %%
# Fit the model to the data.

model.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Print the coefficient and the intercept for the model

print('Weight coefficients: ', model.coef_)
print('y-axis intercept: ', model.intercept_)
# Out:
# Weight coefficients:  [[-92.40111476]]
# y-axis intercept:  [-10805.31905766]

# %%
 # Note: we have to transform our min and max values 
# so they are in the format: array([[ 1.17]])
# This is the required format for `model.predict()`

x_min = np.array([[X.min()]])
x_max = np.array([[X.max()]])
print(f"Min X Value: {x_min}")
print(f"Max X Value: {x_max}")
# Out:
# Min X Value: [[-118.911026]]
# Max X Value: [[-117.6554708]]

# %%
# Calculate the y_min and y_max using model.predict and x_min and x_max

y_min = model.predict(x_min)
y_max = model.predict(x_max)

# %%
# Plot X and y using plt.scatter
# Plot the model fit line using [x_min[0], x_max[0]], [y_min[0], y_max[0]]

plt.scatter(X, y, c='blue')
plt.plot([x_min[0], x_max[0]], [y_min[0], y_max[0]], c='red')
plt.title("Price vs. longitude")

plt.savefig('linear_reg_longitude.png')

# %%
# compute with sklearn linear_model, although could not find any function to compute adjusted-r-square directly from documentation
print (model.score(X, y), 1 - (1-model.score(X, y))*(len(y)-1)/(len(y)-X.shape[1]-1))
# Out:
# 0.028555596686237084 0.02852105644078584

# %%
# compute with statsmodels, by adding intercept manually
import statsmodels.api as sm
X1 = sm.add_constant(X)
result = sm.OLS(y, X1).fit()
#print dir(result)
print (result.rsquared, result.rsquared_adj)
# Out:
# 0.028555596686237195 0.028521056440786063
